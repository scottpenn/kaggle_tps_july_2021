# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, QuantileTransformer
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_squared_log_error
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import chi2, SelectKBest

# %%
train = pd.read_csv('tabular-playground-series-jul-2021/train.csv', parse_dates=['date_time'], index_col='date_time')
test = pd.read_csv('tabular-playground-series-jul-2021/test.csv', parse_dates=['date_time'], index_col='date_time')

# %%
corr = train.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_96697_row0_col0,#T_96697_row1_col1,#T_96697_row2_col2,#T_96697_row3_col3,#T_96697_row4_col4,#T_96697_row5_col5,#T_96697_row6_col6,#T_96697_row7_col7,#T_96697_row8_col8,#T_96697_row9_col9,#T_96697_row10_col10{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_96697_row0_col1,#T_96697_row1_col0,#T_96697_row4_col5,#T_96697_row5_col2,#T_96697_row5_col3,#T_96697_row5_col4,#T_96697_row5_col6,#T_96697_row5_col7,#T_96697_row5_col8,#T_96697_row5_col9,#T_96697_row5_col10{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_96697_row0_col2{
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }#T_96697_row0_col3,#T_96697_row0_col7{
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }#T_96697_row0_col4{
#             background-color:  #e3d9d3;
#             color:  #000000;
#         }#T_96697_row0_col5,#T_96697_row7_col0{
#             background-color:  #b6cefa;
#             color:  #000000;
#         }#T_96697_row0_col6{
#             background-color:  #f2cab5;
#             color:  #000000;
#         }#T_96697_row0_col8{
#             background-color:  #afcafc;
#             color:  #000000;
#         }#T_96697_row0_col9,#T_96697_row1_col7,#T_96697_row2_col7,#T_96697_row4_col2{
#             background-color:  #d9dce1;
#             color:  #000000;
#         }#T_96697_row0_col10{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_96697_row1_col2{
#             background-color:  #dbdcde;
#             color:  #000000;
#         }#T_96697_row1_col3,#T_96697_row1_col4{
#             background-color:  #cad8ef;
#             color:  #000000;
#         }#T_96697_row1_col5{
#             background-color:  #bed2f6;
#             color:  #000000;
#         }#T_96697_row1_col6,#T_96697_row2_col3{
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }#T_96697_row1_col8{
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }#T_96697_row1_col9,#T_96697_row3_col0,#T_96697_row7_col2,#T_96697_row8_col1{
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }#T_96697_row1_col10{
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }#T_96697_row2_col0{
#             background-color:  #f7b89c;
#             color:  #000000;
#         }#T_96697_row2_col1{
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }#T_96697_row2_col4{
#             background-color:  #efcfbf;
#             color:  #000000;
#         }#T_96697_row2_col5{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_96697_row2_col6,#T_96697_row8_col6{
#             background-color:  #f4987a;
#             color:  #000000;
#         }#T_96697_row2_col8{
#             background-color:  #aec9fc;
#             color:  #000000;
#         }#T_96697_row2_col9{
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }#T_96697_row2_col10{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_96697_row3_col1{
#             background-color:  #d1dae9;
#             color:  #000000;
#         }#T_96697_row3_col2,#T_96697_row8_col0{
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }#T_96697_row3_col4,#T_96697_row6_col4{
#             background-color:  #d75445;
#             color:  #000000;
#         }#T_96697_row3_col5{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_96697_row3_col6,#T_96697_row7_col6,#T_96697_row7_col10{
#             background-color:  #ee8669;
#             color:  #000000;
#         }#T_96697_row3_col7,#T_96697_row4_col7{
#             background-color:  #d0473d;
#             color:  #f1f1f1;
#         }#T_96697_row3_col8,#T_96697_row3_col9{
#             background-color:  #d44e41;
#             color:  #000000;
#         }#T_96697_row3_col10{
#             background-color:  #f49a7b;
#             color:  #000000;
#         }#T_96697_row4_col0{
#             background-color:  #d7dce3;
#             color:  #000000;
#         }#T_96697_row4_col1{
#             background-color:  #bad0f8;
#             color:  #000000;
#         }#T_96697_row4_col3{
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }#T_96697_row4_col6,#T_96697_row7_col8{
#             background-color:  #d85646;
#             color:  #000000;
#         }#T_96697_row4_col8{
#             background-color:  #da5a49;
#             color:  #000000;
#         }#T_96697_row4_col9,#T_96697_row9_col4{
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }#T_96697_row4_col10,#T_96697_row6_col8{
#             background-color:  #f6a385;
#             color:  #000000;
#         }#T_96697_row5_col0{
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }#T_96697_row5_col1{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_96697_row6_col0{
#             background-color:  #efcebd;
#             color:  #000000;
#         }#T_96697_row6_col1{
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }#T_96697_row6_col2{
#             background-color:  #f7a98b;
#             color:  #000000;
#         }#T_96697_row6_col3,#T_96697_row10_col3{
#             background-color:  #f18f71;
#             color:  #000000;
#         }#T_96697_row6_col5{
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }#T_96697_row6_col7{
#             background-color:  #ef886b;
#             color:  #000000;
#         }#T_96697_row6_col9,#T_96697_row9_col6{
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }#T_96697_row6_col10{
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }#T_96697_row7_col1{
#             background-color:  #d6dce4;
#             color:  #000000;
#         }#T_96697_row7_col3,#T_96697_row8_col3{
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }#T_96697_row7_col4,#T_96697_row9_col8{
#             background-color:  #cf453c;
#             color:  #f1f1f1;
#         }#T_96697_row7_col5{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_96697_row7_col9,#T_96697_row9_col7{
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }#T_96697_row8_col2{
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }#T_96697_row8_col4,#T_96697_row9_col3{
#             background-color:  #d65244;
#             color:  #000000;
#         }#T_96697_row8_col5{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_96697_row8_col7{
#             background-color:  #d55042;
#             color:  #000000;
#         }#T_96697_row8_col9{
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }#T_96697_row8_col10{
#             background-color:  #e0654f;
#             color:  #000000;
#         }#T_96697_row9_col0{
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }#T_96697_row9_col1{
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }#T_96697_row9_col2{
#             background-color:  #cfdaea;
#             color:  #000000;
#         }#T_96697_row9_col5{
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }#T_96697_row9_col10{
#             background-color:  #f39475;
#             color:  #000000;
#         }#T_96697_row10_col0{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_96697_row10_col1{
#             background-color:  #dedcdb;
#             color:  #000000;
#         }#T_96697_row10_col2{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_96697_row10_col4{
#             background-color:  #f08b6e;
#             color:  #000000;
#         }#T_96697_row10_col5{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_96697_row10_col6{
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }#T_96697_row10_col7{

# %%
columns = set(train.columns) - set(['target_carbon_monoxide', 'target_benzene', 'target_nitrogen_oxides'])
columns_carbon_monoxide = list(columns) + ['target_benzene']
columns_nitrogen_oxides = list(columns) + ['target_carbon_monoxide']
targets = ['target_carbon_monoxide', 'target_benzene', 'target_nitrogen_oxides']

# %%
rf_carbon_monoxide = make_pipeline(StandardScaler(), RandomForestRegressor())
rf_benzene = make_pipeline(StandardScaler(), RandomForestRegressor())
rf_nitrogen_oxides = make_pipeline(StandardScaler(), RandomForestRegressor())

# %%
X_train, X_test, y_train, y_test = train_test_split(train, train[targets], test_size=0.2)

# %%
X_train_carbon_monoxide = X_train[columns_carbon_monoxide]
X_train_benzene = X_train[columns]
X_train_nitrogen_oxides = X_train[columns_nitrogen_oxides]

X_test_carbon_monoxide = X_test[columns_carbon_monoxide]
X_test_benzene = X_test[columns]
X_test_nitrogen_oxides = X_test[columns_nitrogen_oxides]

# %%
y_train_carbon_monoxide = y_train['target_carbon_monoxide']
y_test_carbon_monoxide = y_test['target_carbon_monoxide']

y_train_benzene = y_train['target_benzene']
y_test_benzene = y_test['target_benzene']

y_train_nitrogen_oxides = y_train['target_nitrogen_oxides']
y_test_nitrogen_oxides = y_test['target_nitrogen_oxides']

# %%
rf_benzene.fit(X_train_benzene, y_train_benzene.values)
y_pred_train_benzene = rf_benzene.predict(X_train_benzene)
y_pred_test_benzene = rf_benzene.predict(X_test_benzene)
(mean_squared_log_error(y_train_benzene, y_pred_train_benzene),
 mean_squared_log_error(y_test_benzene, y_pred_test_benzene))
# Out:
# (0.001235014937368321, 0.00872370501003721)

# %%
test['target_benzene'] = rf_benzene.predict(test[columns])

# %%
rf_carbon_monoxide.fit(X_train_carbon_monoxide, y_train_carbon_monoxide.values)
y_pred_train_carbon_monoxide = rf_carbon_monoxide.predict(X_train_carbon_monoxide)
y_pred_test_carbon_monoxide = rf_carbon_monoxide.predict(X_test_carbon_monoxide)
(mean_squared_log_error(y_train_carbon_monoxide, y_pred_train_carbon_monoxide),
 mean_squared_log_error(y_test_carbon_monoxide, y_pred_test_carbon_monoxide))
# Out:
# (0.002411873065074066, 0.01669007094499824)

# %%
test['target_carbon_monoxide'] = rf_carbon_monoxide.predict(test[columns_carbon_monoxide])

# %%
rf_nitrogen_oxides.fit(X_train_nitrogen_oxides, y_train_nitrogen_oxides.values)
y_pred_train_nitrogen_oxides = rf_nitrogen_oxides.predict(X_train_nitrogen_oxides)
y_pred_test_nitrogen_oxides = rf_nitrogen_oxides.predict(X_test_nitrogen_oxides)
(mean_squared_log_error(y_train_nitrogen_oxides, y_pred_train_nitrogen_oxides),
 mean_squared_log_error(y_test_nitrogen_oxides, y_pred_test_nitrogen_oxides))
# Out:
# (0.012134974071959704, 0.07373656325087663)

# %%
test['target_nitrogen_oxides'] = rf_nitrogen_oxides.predict(test[columns_nitrogen_oxides])

# %%
rf_carbon_monoxide.steps[1][1].feature_importances_
# Out:
# array([0.01541529, 0.01981558, 0.01345775, 0.01274465, 0.03188859,
#        0.01995946, 0.10425389, 0.02781555, 0.75464924])

# %%
X_train_carbon_monoxide
# Out:
#                      sensor_2  sensor_5  sensor_4  relative_humidity  \
# date_time
# 2010-04-01 12:00:00     875.0     774.2    1493.5               36.0
# 2010-07-23 04:00:00     720.1    1022.0    1530.0               44.0
# 2010-08-20 03:00:00     544.4     452.6    1452.2               49.2
# 2010-05-19 06:00:00     832.0     761.4    1520.5               53.1
# 2010-12-29 14:00:00     687.3     742.6    1066.0               46.3
# ...                       ...       ...       ...                ...
# 2010-09-04 05:00:00     788.6     903.0    1333.9               50.7
# 2010-07-16 10:00:00     950.0    1040.0    1497.4               32.0
# 2010-10-25 09:00:00    1236.8    1610.9    1859.2               65.0
# 2010-04-07 14:00:00     792.5     626.0    1383.2               50.2
# 2010-05-20 00:00:00     871.7    1029.2    1589.7               48.6
#
#                      absolute_humidity  sensor_3  sensor_1  deg_C  \
# date_time
# 2010-04-01 12:00:00             0.8797    1003.2    1072.6   19.4
# 2010-07-23 04:00:00             1.4801     917.7     848.2   26.1
# 2010-08-20 03:00:00             1.8720    1266.3     775.7   27.9
# 2010-05-19 06:00:00             0.9612     933.8    1019.2   16.9
# 2010-12-29 14:00:00             0.6397     870.0     886.6   11.8
# ...                                ...       ...       ...    ...
# 2010-09-04 05:00:00             1.4337     768.6     929.3   21.4
# 2010-07-16 10:00:00             1.2825     842.1     977.4   29.1
# 2010-10-25 09:00:00             1.4140     520.4    1300.9   18.0
# 2010-04-07 14:00:00             0.8433    1040.3     997.0   15.1
# 2010-05-20 00:00:00             1.0539     771.7    1105.8   17.8
#
#                      target_benzene
# date_time
# 2010-04-01 12:00:00             7.6
# 2010-07-23 04:00:00             3.8
# 2010-08-20 03:00:00             1.3
# 2010-05-19 06:00:00             5.5
# 2010-12-29 14:00:00             4.6
# ...                             ...
# 2010-09-04 05:00:00             4.8
# 2010-07-16 10:00:00             9.8
# 2010-10-25 09:00:00            17.7
# 2010-04-07 14:00:00             6.2
# 2010-05-20 00:00:00             8.2
#
# [5688 rows x 9 columns]

# %%
submission = test[['target_carbon_monoxide', 'target_benzene', 'target_nitrogen_oxides']]

# %%
submission
# Out:
#                      target_carbon_monoxide  target_benzene  \
# date_time
# 2011-01-01 00:00:00                   1.404           4.491
# 2011-01-01 01:00:00                   2.391           7.652
# 2011-01-01 02:00:00                   1.792           7.665
# 2011-01-01 03:00:00                   2.471           8.708
# 2011-01-01 04:00:00                   1.428           6.704
# ...                                     ...             ...
# 2011-04-04 10:00:00                   2.590          12.605
# 2011-04-04 11:00:00                   2.222          10.497
# 2011-04-04 12:00:00                   2.452          12.277
# 2011-04-04 13:00:00                   1.961          11.153
# 2011-04-04 14:00:00                   2.046          12.146
#
#                      target_nitrogen_oxides
# date_time
# 2011-01-01 00:00:00                 206.009
# 2011-01-01 01:00:00                 334.853
# 2011-01-01 02:00:00                 329.924
# 2011-01-01 03:00:00                 366.893
# 2011-01-01 04:00:00                 247.548
# ...                                     ...
# 2011-04-04 10:00:00                 393.111
# 2011-04-04 11:00:00                 348.134
# 2011-04-04 12:00:00                 376.657
# 2011-04-04 13:00:00                 295.075
# 2011-04-04 14:00:00                 333.409
#
# [2247 rows x 3 columns]

# %%
submission.to_csv('my_submission.csv')
